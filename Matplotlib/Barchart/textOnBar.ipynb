# %%
'''
@Author: Ayur Ninawe
@Date: 2021-07-14 17:00:30
@Last Modified by: Ayur Ninawe
@Last Modified time: 2021-07-14 17:00:30
@Title : ​Write a Python programming to display a bar chart of the popularity of programming
Languages. Attach a text label above each bar displaying its popularity (float value).
'''

# %%
from matplotlib import pyplot as plt
from loggerfile import Log

# %%
def textonbar():
    '''
    Describe : function to add text label above each bar displaying its popularity
    '''
    try:
        languages=['Java','Python','PHP','JavaScript','C#','C++']
        popularity=[22.2,17.6,8.8,8,7.7,6.7]

        fig,axis=plt.subplots()
        bars=axis.bar(languages,popularity,color='blue')
        plt.xlabel("Programming Languages",color='maroon')
        plt.ylabel("Popularity",color='maroon')
        plt.title("Popularity of programming languages", color='black')
        plt.minorticks_on()

        for bar in bars:
            axis.text(bar.get_x()+bar.get_width()/2.,1*(bar.get_height()),'%f' % float(bar.get_height()), ha='center', va='bottom')
        plt.show()
    except Exception as e:
        loggerfile.Log.logging.error(e)

# %%
textonbar()
