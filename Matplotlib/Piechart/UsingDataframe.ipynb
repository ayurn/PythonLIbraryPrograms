# %%
'''
@Author: Ayur Ninawe
@Date: 2021-07-15 15:00:30
@Last Modified by: Ayur Ninawe
@Last Modified time: 2021-07-15 15:00:30
@Title : Write a Python programming to create a pie chart of gold medal achievements of five most
successful countries in 2016 Summer Olympics. Read the data from a csv file.
'''

# %%
from matplotlib import pyplot as plt
import pandas as pd
from loggerfile import Log

# %%
try:
    dataFrame=pd.read_csv("Medal.csv")
    dataFrame.set_index("country",inplace=True)
    plt.title("Gold medal achievements of five most successful countries in 2016 Summer Olympics")
    plt.pie(dataFrame["gold_medal"],labels=dataFrame.index,autopct="%1.2f%%")
    plt.show()
except Exception as e:
        loggerfile.Log.logging.error(e)
