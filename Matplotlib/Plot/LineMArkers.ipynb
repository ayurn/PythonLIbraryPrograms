# %%
'''
@Author: Ayur Ninawe
@Date: 2021-07-14 14:00:30
@Last Modified by: Ayur Ninawe
@Last Modified time: 2021-07-14 14:00:30
@Title : ​ Write a Python program to plot two or more lines and set the line markers.
'''

# %%
from matplotlib import pyplot as plt
from matplotlib import style
from loggerfile import Log

# %%
def markers():
    '''
    Description : plot two or more lines and set the line markers.
    '''
    try:
        x=[1,2,3,4,5]
        plt.plot(x,[9,8,7,6,5],"-.")
        plt.plot(x,[4,3,2,1,1],"--")
        plt.plot(x,[0,0,9,0,0],':')
        plt.xlabel("y-axis")
        plt.ylabel("x-axis")
        plt.title("Line Markers")
        plt.show()
    except Exception as e:
        loggerfile.Log.logging.error(e)

# %%
markers()
