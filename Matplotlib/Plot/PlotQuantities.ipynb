# %%
'''
@Author: Ayur Ninawe
@Date: 2021-07-14 14:00:30
@Last Modified by: Ayur Ninawe
@Last Modified time: 2021-07-14 14:00:30
@Title : Write a Python program to plot quantities which have an x and y position.
'''

# %%
from matplotlib import pyplot as plt
from matplotlib import style
from loggerfile import Log

# %%
def quantities():
    '''
    Description : plot quantities which have an x and y position.
    '''
    try:
        x=[1,2,3,4,5]
        y=[3,2,6,4,3]
        x1=[1,2,3,4,5]
        y1=[9,8,7,5,1]
        plt.plot(x,y,"bs",x1,y1,"ro")
        plt.show()
    except Exception as e:
        loggerfile.Log.logging.error(e)

# %%
quantities()
