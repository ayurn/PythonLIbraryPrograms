# %%
'''
@Author: Ayur Ninawe
@Date: 2021-07-15 16:00:30
@Last Modified by: Ayur Ninawe
@Last Modified time: 2021-07-15 16:00:30
@Title : Write a program to draw swarm plot of “total bill” against day for a dataset given in url
https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv
'''

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from loggerfile import Log

# %%
try:
    data = pd.read_csv('tips.csv')

    x = data['day']
    y = data['total_bill']

    plt.figure(figsize = (8,8))
    sns.swarmplot(x,y)
    plt.xlabel('Day', fontsize = 20)
    plt.ylabel('Total Bill', fontsize = 20)
    plt.show()
except Exception as e:
        loggerfile.Log.logging.error(e)
# Out:
# /home/ayur/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
